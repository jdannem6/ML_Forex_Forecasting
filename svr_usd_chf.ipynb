# %% [markdown]
# # Load Data

# %%
import os
import sys

feat_dir = os.path.join('..', 'ML_Forex_Forecasting')
sys.path.append(feat_dir)

# %%
import pandas as pd
from generate_features import generate_features

# %%
usd_eur = pd.read_csv(os.path.join(feat_dir, "./USDEUR=X.csv"), parse_dates=['Date'])
eur_chf = pd.read_csv(os.path.join(feat_dir, "./EURCHF=X.csv"), parse_dates=['Date'])
eur_gbp = pd.read_csv(os.path.join(feat_dir, "./EURGBP=X.csv"), parse_dates=['Date'])
gbp_chf = pd.read_csv(os.path.join(feat_dir, "./GBPCHF=X.csv"), parse_dates=['Date'])
usd_chf = pd.read_csv(os.path.join(feat_dir, "./USDCHF=X.csv"), parse_dates=['Date'])
usd_gbp = pd.read_csv(os.path.join(feat_dir, "./USDGBP=X.csv"), parse_dates=['Date'])

# %%
data = usd_chf

# %%
feats = generate_features(data)
print(f"EUR/CHF Features shape: {feats.shape}")
display(feats.head())
# Out:
# EUR/CHF Features shape: (262, 28)
#         Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0 2023-11-04         0.904953      1.000000       1.000124        0.000366
# 1 2023-11-03         0.904123      1.000000       1.000192       -0.003185
# 2 2023-11-02         0.901706      1.000000       1.000731       -0.003333
# 3 2023-11-01         0.898767      1.000000       1.000392       -0.003243
# 4 2023-10-31         0.896256      1.018195       1.000557       -0.003197
#
#    opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0            0.905610            0.215978             1.072017
# 1            0.905757           -0.002462             0.847445
# 2            0.905607           -0.141231             0.843288
# 3            0.905264           -0.072246             1.006131
# 4            0.904894            0.177432             1.264659
#
#    opt_fourier_cosphase  opt_fourier_sinamp  ...       ROC1       ROC5  \
# 0             -4.397565           -0.215485  ...  84.982082  34.598417
# 1             -0.969690            0.002326  ...  -5.271008 -42.379707
# 2              0.835033           -0.141714  ...  68.720892 -45.891929
# 3              0.495066           -0.072345  ... -55.585732 -73.022514
# 4              0.372684            0.177539  ...   2.502864 -45.145772
#
#          ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0   151.006874 -4255.357016  45.974653 -12.086767 -0.013364 -0.012377
# 1   191.195203 -4216.877859  55.677407  14.462076 -0.011106 -0.008642
# 2 -1768.006304 -4219.397328  55.101292  12.912282 -0.012225 -0.009451
# 3  -224.046896 -4199.928706  60.769001  29.190840 -0.013553 -0.010532
# 4  -826.910775 -4364.310045  52.507979   7.281077 -0.017558 -0.015624
#
#      STOCH14    Close
# 0  45.974653  0.89770
# 1  55.677407  0.90610
# 2  55.101292  0.90555
# 3  60.769001  0.90980
# 4  52.507979  0.90206
#
# [5 rows x 28 columns]

# %%
feats.columns
# Out:
# Index(['Date', 'opt_sine_offset', 'opt_sine_amp', 'opt_sine_freq',
#        'opt_sine_phase', 'opt_fourier_offset', 'opt_fourier_cosamp',
#        'opt_fourier_cosfreq', 'opt_fourier_cosphase', 'opt_fourier_sinamp',
#        'opt_fourier_sinfreq', 'opt_fourier_sinphase', 't', 'Slopes',
#        'autocorrelation', 'pca', 'ica', 'mean_abs', 'ROC1', 'ROC5', 'ROC20',
#        'WILLIAMS14', 'RSI14', 'CMO9', 'DEMA9', 'TEMA9', 'STOCH14', 'Close'],
#       dtype='object')

# %% [markdown]
# # 1. Prepare X_train, Y_train, X_test, Y_test

# %%
from sklearn.model_selection import train_test_split

# %%
# use the past 20 days to train the model
def prepare_train_test(df: pd.DataFrame, n_lag_features: int = 10, test_size: float = 0.2, n_days_ahead: int = 5):
    df = df.copy()
    df.drop(['t'], axis=1)
    XY = []
    
    for col in df.columns:
        if col == 'Close':
            closes = pd.DataFrame()
            for i in range(1, n_days_ahead + 1):
                lag_feature_name = f'{col}_Day_{i}'
                closes[lag_feature_name] = df[col].shift(i)
            XY.append(closes)
        elif col != 'Date':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            XY.append(col_lag_features)
    df = pd.concat(XY, axis=1)
    df.dropna(inplace=True)
    
    Y_columns = [f'{col}_Day_{i}' for i in range(1, n_days_ahead + 1)]
    Y = df[Y_columns]
    X = df.drop(columns=Y_columns, axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
n_days_ahead = 5 # predict the next 5 days
n_lag_features = 10 # how many past days used for predictions

# %%
X_train, X_test, Y_train, Y_test = prepare_train_test(feats, n_lag_features=n_lag_features, n_days_ahead=n_days_ahead)

# %%
X_train.head()
# Out:
#      opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 160               0.922198               0.924534               0.927799
# 217               0.926264               0.925552               0.926932
# 123               0.893521               0.892303               0.890688
# 201               0.919571               0.918981               0.918806
# 221               0.930640               0.930482               0.929662
#
#      opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 160               0.926587               0.922628               0.921225
# 217               0.929085               0.930640               0.930482
# 123               0.889399               0.887903               0.888208
# 201               0.919558               0.921023               0.923582
# 221               0.928949               0.929053               0.928971
#
#      opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 160               0.920953               0.923630               0.929413
# 217               0.929662               0.928949               0.929053
# 123               0.889439               0.890198               0.892291
# 201               0.926408               0.926882               0.925455
# 221               0.928279               0.928957               0.929933
#
#      opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 160               0.933763  ...      45.206825      42.238486      42.311461
# 217               0.928971  ...      44.670337      50.202458      36.278439
# 123               0.893747  ...      50.019502      49.016600      52.208172
# 201               0.925681  ...      43.890214      40.132544      44.721765
# 221               0.930291  ...      34.724167      38.346135      39.519656
#
#      STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  \
# 160      45.309918      50.499288      48.765257      50.384180
# 217      35.996782      34.724167      38.346135      39.519656
# 123      47.441552      41.628267      42.433273      42.134690
# 201      44.019161      42.087995      37.120356      37.419085
# 221      41.757553      42.448617      40.471830      35.313963
#
#      STOCH14_Lag_7  STOCH14_Lag_8  STOCH14_Lag_9
# 160      51.601773      39.545541      37.796834
# 217      41.757553      42.448617      40.471830
# 123      43.182908      36.199727      33.952260
# 201      41.649030      44.350391      45.398377
# 221      35.191927      36.675499      40.309735
#
# [5 rows x 260 columns]

# %%
Y_train.head() # closing prices for the next 1-5 days
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 160     0.915020      0.92040      0.91810      0.91338      0.91751
# 217     0.935830      0.92687      0.92093      0.92224      0.93092
# 123     0.898742      0.90487      0.89819      0.89830      0.90131
# 201     0.920860      0.92528      0.91625      0.90726      0.91320
# 221     0.923800      0.92400      0.93580      0.92959      0.93583

# %% [markdown]
# ## Scale features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Reduce feature size

# %%
from sklearn.decomposition import PCA

n_components = 10
pca = PCA(n_components=n_components)

X_train_scaled_reduced = pca.fit_transform(X_train_scaled)
X_test_scaled_reduced = pca.transform(X_test_scaled)

# %% [markdown]
# ## Scale Ys

# %%
from sklearn.preprocessing import StandardScaler

scaler_y = StandardScaler()

Y_train_scaled = scaler_y.fit_transform(Y_train)
Y_test_scaled = scaler_y.transform(Y_test)

# %% [markdown]
# # 2. Train SVR

# %%
from sklearn.svm import SVR

import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
Y_train_scaled.shape
# Out:
# (198, 5)

# %%
# svrs: [svr_d1, svr_d2, svr_d3, svr_d4, svr_d5], a model for each day
svrs = []
for i in range(0, n_days_ahead):
    svr = SVR(kernel='rbf', C=1.0, gamma='scale')
    svr.fit(X_train_scaled_reduced, Y_train_scaled[:, i])
    svrs.append(svr)

# %%
pred_train = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    pred_train[f'Close_Day_{i}'] = svrs[i-1].predict(X_train_scaled_reduced)
pred_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0       0.530453     0.621641     0.698558     0.509469     0.537159
# 1       0.966480     0.881024     0.848142     0.872816     1.076101
# 2      -0.417959    -0.387996    -0.391374    -0.349238    -0.286802
# 3       0.628738     0.655770     0.626302     0.594251     0.714991
# 4       0.942949     0.974723     1.189875     1.102856     1.143074
# ..           ...          ...          ...          ...          ...
# 193     0.211790     0.134078     0.195771     0.126202     0.001263
# 194     0.042492    -0.097276     0.051197    -0.033885    -0.241821
# 195    -0.434689    -0.521030    -0.412182    -0.428833    -0.477955
# 196     0.796563     0.997462     1.133887     1.095329     1.099699
# 197     0.068503     0.007020     0.132886     0.046599    -0.111307
#
# [198 rows x 5 columns]

# %%
mse = mean_squared_error(Y_train_scaled, pred_train)
mse
# Out:
# 0.053338546956895015

# %%
# transform back to the original scale
Y_train_pred = scaler_y.inverse_transform(pred_train)
mse = mean_squared_error(Y_train, Y_train_pred)
mse
# Out:
# 2.3497139869851963e-05

# %%
Y_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
#
# 29    -0.349408    -0.430006    -0.327752    -0.368728    -0.452944
# 30     0.879603     0.975113     1.077486     1.033266     0.924710
# 31     1.576619     1.652567     1.692922     1.748946     1.684375
# 32    -0.394185    -0.327109    -0.316386    -0.290725    -0.245544
# 33     0.074026     0.150857     0.241414     0.368801     0.481464
# 34     1.368358     1.331811     1.306095     1.291277     1.307006
# 35     0.515033     0.460486     0.302443     0.198901     0.028834
# 36    -0.554335    -0.532134    -0.623605    -0.629455    -0.611696
# 37     0.795243     0.810994     0.784996     0.710526     0.709173
# 38    -1.224871    -1.170385    -1.211241    -1.228319    -1.239633
# 39    -0.981475    -0.937039    -0.893969    -0.867819    -0.864765
# 40     1.345794     1.371682     1.486281     1.410085     1.389979
# 41     0.117709     0.134696     0.195697     0.131608     0.104977
# 42    -1.391222    -1.416354    -1.397370    -1.432424    -1.363734
# 43     0.847049     0.966190     1.067694     1.041734     0.983814
# 44     0.394905     0.211958     0.152104     0.141975    -0.044139
# 45    -0.503634    -0.464674    -0.444988    -0.387046    -0.307266
# 46    -1.481291    -1.674370    -1.427228    -1.422599    -1.390964
# 47     0.869960     0.958862     1.039611     1.086404     1.102604
# 48    -0.875086    -0.783185    -0.724799    -0.657496    -0.600928
# 49     1.442411     1.553228     1.659922     1.444141     1.319723

# %%
mse = mean_squared_error(Y_test_scaled, pred_test)
mse
# Out:
# 0.08538190735498377

# %%
# transform back to the original scale
Y_test_pred = scaler_y.inverse_transform(pred_test)
mse = mean_squared_error(Y_test, Y_test_pred)
mse
# Out:
# 3.7837948744713444e-05

# %%
Y_test
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 38       0.89320     0.896400     0.896880      0.89725     0.897310
# 11       0.89320     0.890600     0.893060      0.89670     0.898830
# 187      0.92646     0.925350     0.923180      0.92750     0.931240
# 91       0.89500     0.895800     0.896640      0.89852     0.895280
# 161      0.91990     0.915020     0.920400      0.91810     0.913380
# 251      0.95333     0.958430     0.951090      0.94070     0.943370
# 200      0.92528     0.916250     0.907260      0.91320     0.926330
# 109      0.90713     0.909540     0.898700      0.90320     0.908300
# 14       0.90011     0.898570     0.891790      0.89320     0.890600
# 240      0.94230     0.942030     0.940270      0.93586     0.934990
# 237      0.93586     0.934990     0.935740      0.92898     0.924350
# 241      0.93645     0.942300     0.942030      0.94027     0.935860
# 243      0.94388     0.936390     0.936450      0.94230     0.942030
# 183      0.93124     0.933690     0.940030      0.93560     0.941868
# 71       0.86982     0.871650     0.872380      0.87731     0.874220
# 163      0.91652     0.916400     0.919900      0.91502     0.920400
# 197      0.91320     0.926330     0.927870      0.92165     0.920910
# 20       0.90484     0.904550     0.900990      0.90782     0.902490
# 188      0.92336     0.926460     0.925350      0.92318     0.927500
# 29       0.91576     0.920820     0.914760      0.91548     0.917900
# 125      0.89546     0.896350     0.898742      0.90487     0.898190
# 24       0.92097     0.916610     0.912590      0.90870     0.904840
# 117      0.90505     0.905690     0.904460      0.90580     0.909890
# 72       0.86885     0.869820     0.871650      0.87238     0.877310
# 227      0.93100     0.932880     0.932010      0.92920     0.927710
# 228      0.92630     0.931000     0.932880      0.93201     0.929200
#        [0.87544001, 0.87271125, 0.87851427, 0.87730434, 0.87788176],
#        [0.92815587, 0.92537772, 0.92565381, 0.92512315, 0.92609252],
#        [0.92669513, 0.92368611, 0.92443603, 0.92647941, 0.92664392],
#        [0.92114615, 0.923009  , 0.92323684, 0.91920324, 0.91637219],
#        [0.90603214, 0.90262262, 0.90574692, 0.90473645, 0.90021896],
#        [0.89905761, 0.90047829, 0.90209636, 0.90390605, 0.90558763],
#        [0.8980652 , 0.89606644, 0.89818061, 0.89709463, 0.89511361],
#        [0.92446213, 0.92584094, 0.92790595, 0.92642651, 0.92341726],
#        [0.93943277, 0.9401962 , 0.94092442, 0.94139964, 0.93902443],
#        [0.89710347, 0.89824684, 0.89842104, 0.89872658, 0.89937459],
#        [0.9071598 , 0.90837494, 0.91022032, 0.91252487, 0.91431084],
#        [0.93495971, 0.93339939, 0.93274178, 0.9318245 , 0.93127146],
#        [0.91663182, 0.91493598, 0.91151128, 0.90897031, 0.90501165],
#        [0.89366374, 0.89390234, 0.89192234, 0.89163983, 0.89185207],
#        [0.92265022, 0.92236327, 0.92171884, 0.91967429, 0.91898908],
#        [0.87926184, 0.8803778 , 0.87949194, 0.87911066, 0.87895121],
#        [0.88448954, 0.88532241, 0.88620327, 0.88665287, 0.88665281],
#        [0.93447507, 0.93424425, 0.9365533 , 0.93431015, 0.93297613],
#        [0.90809801, 0.9080325 , 0.90925325, 0.90756244, 0.90657598],
#        [0.87568893, 0.87516572, 0.8755547 , 0.87484046, 0.87640158],
#        [0.92376293, 0.92565187, 0.92769882, 0.92660368, 0.92463153],
#        [0.91405169, 0.90966968, 0.90833111, 0.90777932, 0.90351243],
#        [0.8947527 , 0.89533184, 0.89570068, 0.89671138, 0.89810652],
#        [0.8737544 , 0.86969834, 0.87492312, 0.87504602, 0.87584215],
#        [0.924255  , 0.9254966 , 0.92710478, 0.92753823, 0.92707205],
#        [0.88677458, 0.88858257, 0.88978177, 0.89105317, 0.89207328],
#        [0.93655022, 0.93809122, 0.94022638, 0.93502265, 0.93153273]])

# %%
df_test_pred_d1 = pd.DataFrame(Y_test_pred[:,0], Y_test.index)

# %%
df_test_pred_d1 = df_test_pred_d1.sort_index()

# %%
df_test = Y_test.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_1'], marker='o')

# %%
df_test_pred_d2 = pd.DataFrame(Y_test_pred[:,1], Y_test.index)

# %%
df_test_pred_d2 = df_test_pred_d2.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_2'], marker='o')

# %% [markdown]
# # Predict next 5 days

# %%
feats
# Out:
#           Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0   2023-11-04         0.904953      1.000000       1.000124        0.000366
# 1   2023-11-03         0.904123      1.000000       1.000192       -0.003185
# 2   2023-11-02         0.901706      1.000000       1.000731       -0.003333
# 3   2023-11-01         0.898767      1.000000       1.000392       -0.003243
# 4   2023-10-31         0.896256      1.018195       1.000557       -0.003197
# ..         ...              ...           ...            ...             ...
# 257 2022-11-10         0.997987      1.000000       0.999582       -0.000539
# 258 2022-11-09         1.000338      0.992253       0.999516        0.003374
# 259 2022-11-08         1.003518      1.002636       0.999268        0.001566
# 260 2022-11-07         1.002761      1.395380       1.000733       -0.004310
# 261 2022-11-04         0.998216      1.006242       1.000708       -0.004290
#
#      opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0              0.905610            0.215978             1.072017
# 1              0.905757           -0.002462             0.847445
# 2              0.905607           -0.141231             0.843288
# 3              0.905264           -0.072246             1.006131
# 4              0.904894            0.177432             1.264659
# ..                  ...                 ...                  ...
# 257            0.995963           -0.608212             0.969817
# 258            0.996538           -0.852158             0.961759
# 259            0.996713           -0.004760             1.069634
# 260            0.996701           -0.138699             1.065864
# 261            0.996553           -0.211265             1.031455
#
#      opt_fourier_cosphase  opt_fourier_sinamp  ...       ROC1       ROC5  \
# 0               -4.397565           -0.215485  ...  84.982082  34.598417
# 1               -0.969690            0.002326  ...  -5.271008 -42.379707
# 2                0.835033           -0.141714  ...  68.720892 -45.891929
# 3                0.495066           -0.072345  ... -55.585732 -73.022514
# 4                0.372684            0.177539  ...   2.502864 -45.145772
# ..                    ...                 ...  ...        ...        ...
# 257              0.830693           -0.609766  ...  -1.387559 -22.658654
# 258              3.766179           -0.851395  ...  -6.077187 -18.216446
# 259             -1.830722           -0.004564  ...  -9.733076 -14.667741
# 260             -2.274728            0.138444  ... -17.119006   0.410317
# 261              0.759253           -0.211083  ...  11.615711  30.864047
#
#            ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0     151.006874 -4255.357016  45.974653 -12.086767 -0.013364 -0.012377
# 1     191.195203 -4216.877859  55.677407  14.462076 -0.011106 -0.008642
# 2   -1768.006304 -4219.397328  55.101292  12.912282 -0.012225 -0.009451
# 3    -224.046896 -4199.928706  60.769001  29.190840 -0.013553 -0.010532
# 4    -826.910775 -4364.310045  52.507979   7.281077 -0.017558 -0.015624
# ..           ...          ...        ...        ...       ...       ...
# 257   -17.062716 -1963.214006  42.364945 -21.601325  0.073269  0.069938
# 258   -16.112123 -2762.815873  42.969276 -20.200113  0.077081  0.074358
# 259   -12.726643 -3033.283210  45.798136 -13.728942  0.081971  0.080726
# 260     2.774399 -3053.201820  51.369951  -0.895766  0.086552  0.087274
# 261    31.695373 -2998.674196  67.568788  38.434817  0.088917  0.091278
#
#        STOCH14    Close
# 0    45.974653  0.89770
# 1    55.677407  0.90610
# 2    55.101292  0.90555
# 3    60.769001  0.90980
# 4    52.507979  0.90206
# ..         ...      ...
# 257  42.364945  0.98350
# 258  42.969276  0.98445
# 259  45.798136  0.98888
# 260  51.369951  0.99674
# 261  67.568788  1.01342
#
# [262 rows x 28 columns]

# %%
def prepare_for_pred(df: pd.DataFrame, n_lag_features: int = 10):
    df = df.copy()
    df.drop(['t'], axis=1)
    X = []
    
    for col in df.columns:
        if col == 'Date':
            X.append(df[col])
        elif col != 'Close':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            X.append(col_lag_features)
        
    df = pd.concat(X, axis=1)
    df.dropna(inplace=True)
    return df

# %%
input_feats = prepare_for_pred(feats, n_lag_features).iloc[[0]]
input_feats
# Out:
#         Date  opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  \
# 0 2023-11-04               0.904953               0.904123
#
#    opt_sine_offset_Lag_2  opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  \
# 0               0.901706               0.898767               0.896256
#
#    opt_sine_offset_Lag_5  opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  \
# 0                0.89434                0.89308               0.893069
#
#    opt_sine_offset_Lag_8  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.895026  ...      45.974653      55.677407      55.101292
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      60.769001      52.507979      52.962893      48.623017      45.855315
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      40.794126      37.104654
#
# [1 rows x 261 columns]

# %%
input_feats = input_feats.drop(columns=['Date'])
input_feats
# Out:
#    opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 0               0.904953               0.904123               0.901706
#
#    opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 0               0.898767               0.896256                0.89434
#
#    opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 0                0.89308               0.893069               0.895026
#
#    opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.896682  ...      45.974653      55.677407      55.101292
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      60.769001      52.507979      52.962893      48.623017      45.855315
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      40.794126      37.104654
#
# [1 rows x 260 columns]

# %%
input_feats_scaled = scaler.transform(input_feats)

# %%
input_feats_scaled_reduced = pca.transform(input_feats_scaled)

# %%
preds_scaled = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    preds_scaled[f'Close_Day_{i}'] = svrs[i-1].predict(input_feats_scaled_reduced)
preds_scaled
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0     0.023465     0.009877     0.076592     0.131631     0.100079

# %%
preds_unscaled = scaler_y.inverse_transform(preds_scaled)

# %%
pd.DataFrame(preds_unscaled, columns=preds_scaled.columns)
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0     0.906074     0.905388     0.906734     0.907563     0.906475

# %%
outfile = 'predictions_T_svr.csv'

# Save the NumPy matrix to the CSV file (append mode)
with open(outfile, 'a') as f:
    np.savetxt(f, preds_unscaled, delimiter=',')
