# %% [markdown]
# # Load Data

# %%
import os
import sys

feat_dir = os.path.join('..', 'ML_Forex_Forecasting')
sys.path.append(feat_dir)

# %%
import pandas as pd
from generate_features import generate_features

# %%
usd_eur = pd.read_csv(os.path.join(feat_dir, "./USDEUR=X.csv"), parse_dates=['Date'])
usd_gbp = pd.read_csv(os.path.join(feat_dir, "./USDGBP=X.csv"), parse_dates=['Date'])
usd_chf = pd.read_csv(os.path.join(feat_dir, "./USDCHF=X.csv"), parse_dates=['Date'])
eur_gbp = pd.read_csv(os.path.join(feat_dir, "./EURGBP=X.csv"), parse_dates=['Date'])
eur_chf = pd.read_csv(os.path.join(feat_dir, "./EURCHF=X.csv"), parse_dates=['Date'])
gbp_chf = pd.read_csv(os.path.join(feat_dir, "./GBPCHF=X.csv"), parse_dates=['Date'])
# print(f"USD/EUR: {usd_eur.shape}")
# display(usd_eur.head())
# print(f"USD/GBP: {usd_gbp.shape}")
# display(usd_gbp.head())
# print(f"USD/CHF: {usd_chf.shape}")
# display(usd_chf.head())
# print(f"EUR/GBP: {eur_gbp.shape}")
# display(eur_gbp.head())
print(f"EUR/CHF: {eur_chf.shape}")
display(eur_chf.head())
# print(f"GBP/CHF: {gbp_chf.shape}")
# display(gbp_chf.head())
# Out:
# EUR/CHF: (284, 7)
#         Date     Open     High      Low    Close  Adj Close  Volume
# 0 2022-10-05  0.97714  0.97961  0.97043  0.97714    0.97714       0
# 1 2022-10-06  0.97264  0.97379  0.96920  0.97264    0.97264       0
# 2 2022-10-07  0.96909  0.97137  0.96770  0.96909    0.96909       0
# 3 2022-10-10  0.96790  0.97216  0.96600  0.96790    0.96790       0
# 4 2022-10-11  0.97051  0.97136  0.96690  0.97051    0.97051       0

# %%
# usd_eur_feats = generate_features(usd_eur)
# print(f"USD/EUR Features shape: {usd_eur_feats.shape}")
# display(usd_eur_feats.head())

# usd_gbp_feats = generate_features(usd_gbp)
# print(f"USD/GBP Features shape: {usd_gbp_feats.shape}")
# display(usd_gbp_feats.head())

# usd_chf_feats = generate_features(usd_chf)
# print(f"USD/CHF Features shape: {usd_chf_feats.shape}")
# display(usd_chf_feats.head())

# eur_gbp_feats = generate_features(eur_gbp)
# print(f"EUR/GBP Features shape: {eur_gbp_feats.shape}")
# display(eur_gbp_feats.head())

eur_chf_feats = generate_features(eur_chf)
print(f"EUR/CHF Features shape: {eur_chf_feats.shape}")
display(eur_chf_feats.head())

# gbp_chf_feats = generate_features(gbp_chf)
# print(f"GBP/CHF Features shape: {gbp_chf_feats.shape}")
# display(gbp_chf_feats.head())
# Out:
# EUR/CHF Features shape: (262, 28)
#         Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0 2023-11-04         0.958614      1.000000       1.000522       -0.002749
# 1 2023-11-03         0.956503      1.000000       1.000285       -0.003062
# 2 2023-11-02         0.953924      1.002997       1.000698       -0.003977
# 3 2023-11-01         0.950673      1.000000       1.000542       -0.003011
# 4 2023-10-31         0.949086      1.000000       1.000065        0.000835
#
#    opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0            0.957463            0.052632             0.938212
# 1            0.957482            0.001027             1.193877
# 2            0.957282           -0.068468             1.020909
# 3            0.957335            0.068881             1.054420
# 4            0.957217            0.093351             1.117052
#
#    opt_fourier_cosphase  opt_fourier_sinamp  ...       ROC1       ROC5  \
# 0             -0.001767            0.052491  ... -14.041234 -45.814813
# 1             -1.520623           -0.000813  ... -17.715717 -45.248288
# 2             -0.487678           -0.068968  ...  26.257384 -38.147481
# 3             -2.563270           -0.068181  ... -25.509741 -53.055586
# 4             -2.027260            0.094565  ... -18.545095 -26.839844
#
#        ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0 -21.733902 -4268.541269  60.493388  29.135814 -0.015573 -0.012660
# 1   4.763255 -4277.711575  58.312440  23.856903 -0.017820 -0.014858
# 2  33.001729 -4615.126767  54.756242  15.132448 -0.019971 -0.016985
# 3  13.928513 -4670.439535  60.369975  30.989510 -0.021409 -0.018125
# 4  30.001445 -4758.584347  54.751880  17.681247 -0.025344 -0.022992
#
#      STOCH14    Close
# 0  60.493388  0.96398
# 1  58.312440  0.96188
# 2  54.756242  0.95866
# 3  60.369975  0.96244
# 4  54.751880  0.95751
#
# [5 rows x 28 columns]

# %%
eur_chf_feats.columns
# Out:
# Index(['Date', 'opt_sine_offset', 'opt_sine_amp', 'opt_sine_freq',
#        'opt_sine_phase', 'opt_fourier_offset', 'opt_fourier_cosamp',
#        'opt_fourier_cosfreq', 'opt_fourier_cosphase', 'opt_fourier_sinamp',
#        'opt_fourier_sinfreq', 'opt_fourier_sinphase', 't', 'Slopes',
#        'autocorrelation', 'pca', 'ica', 'mean_abs', 'ROC1', 'ROC5', 'ROC20',
#        'WILLIAMS14', 'RSI14', 'CMO9', 'DEMA9', 'TEMA9', 'STOCH14', 'Close'],
#       dtype='object')

# %% [markdown]
# # 1. Prepare X_train, Y_train, X_test, Y_test

# %%
from sklearn.model_selection import train_test_split

# %%
# use the past 20 days to train the model
def prepare_train_test(df: pd.DataFrame, n_lag_features: int = 10, test_size: float = 0.2, n_days_ahead: int = 5):
    df = df.copy()
    df.drop(['t'], axis=1)
    XY = []
    
    for col in df.columns:
        if col == 'Close':
            closes = pd.DataFrame()
            for i in range(1, n_days_ahead + 1):
                lag_feature_name = f'{col}_Day_{i}'
                closes[lag_feature_name] = df[col].shift(i)
            XY.append(closes)
        elif col != 'Date':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            XY.append(col_lag_features)
    df = pd.concat(XY, axis=1)
    df.dropna(inplace=True)
    
    Y_columns = [f'{col}_Day_{i}' for i in range(1, n_days_ahead + 1)]
    Y = df[Y_columns]
    X = df.drop(columns=Y_columns, axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
n_days_ahead = 5 # predict the next 5 days
n_lag_features = 10 # how many past days used for predictions

# %%
X_train, X_test, Y_train, Y_test = prepare_train_test(eur_chf_feats, n_lag_features=n_lag_features, n_days_ahead=n_days_ahead)

# %%
X_train.head()
# Out:
#      opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 160               0.993967               0.991998               0.990188
# 217               0.986207               0.986724               0.987395
# 123               0.975441               0.976269               0.977719
# 201               1.000192               0.997266               0.995190
# 221               0.989023               0.988397               0.987267
#
#      opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 160               0.987635               0.984088               0.982423
# 217               0.988347               0.989023               0.988397
# 123               0.977970               0.977862               0.979371
# 201               0.995111               0.996099               0.999121
# 221               0.986030               0.985494               0.985857
#
#      opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 160               0.982458               0.983940               0.986722
# 217               0.987267               0.986030               0.985494
# 123               0.979960               0.980715               0.983040
# 201               1.002270               1.001218               0.998269
# 221               0.986414               0.987229               0.987210
#
#      opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 160               0.989993  ...      48.709490      52.730090      56.855820
# 217               0.985857  ...      49.446281      51.601597      50.923312
# 123               0.984154  ...      37.888781      36.818506      38.432758
# 201               0.995117  ...      59.503374      58.908639      62.251275
# 221               0.986240  ...      46.375637      49.905344      54.066105
#
#      STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  \
# 160      53.142966      57.302125      49.973613      45.397742
# 217      52.770965      46.375637      49.905344      54.066105
# 123      39.413341      40.716232      39.520230      42.515858
# 201      60.413799      58.183133      51.011795      47.437588
# 221      59.665693      58.907237      53.201513      45.993397
#
#      STOCH14_Lag_7  STOCH14_Lag_8  STOCH14_Lag_9
# 160      44.414154      37.733474      33.748393
# 217      59.665693      58.907237      53.201513
# 123      46.774920      35.912685      38.217047
# 201      54.140745      65.736822      66.948863
# 221      48.097166      50.390293      57.263313
#
# [5 rows x 260 columns]

# %%
X_train.columns.tolist()
# Out:
# ['opt_sine_offset_Lag_0',
#  'opt_sine_offset_Lag_1',
#  'opt_sine_offset_Lag_2',
#  'opt_sine_offset_Lag_3',
#  'opt_sine_offset_Lag_4',
#  'opt_sine_offset_Lag_5',
#  'opt_sine_offset_Lag_6',
#  'opt_sine_offset_Lag_7',
#  'opt_sine_offset_Lag_8',
#  'opt_sine_offset_Lag_9',
#  'opt_sine_amp_Lag_0',
#  'opt_sine_amp_Lag_1',
#  'opt_sine_amp_Lag_2',
#  'opt_sine_amp_Lag_3',
#  'opt_sine_amp_Lag_4',
#  'opt_sine_amp_Lag_5',
#  'opt_sine_amp_Lag_6',
#  'opt_sine_amp_Lag_7',
#  'opt_sine_amp_Lag_8',
#  'opt_sine_amp_Lag_9',
#  'opt_sine_freq_Lag_0',
#  'opt_sine_freq_Lag_1',
#  'opt_sine_freq_Lag_2',
#  'opt_sine_freq_Lag_3',
#  'opt_sine_freq_Lag_4',
#  'opt_sine_freq_Lag_5',
#  'opt_sine_freq_Lag_6',
#  'opt_sine_freq_Lag_7',
#  'opt_sine_freq_Lag_8',
#  'opt_sine_freq_Lag_9',
#  'opt_sine_phase_Lag_0',
#  'opt_sine_phase_Lag_1',
#  'opt_sine_phase_Lag_2',
#  'opt_sine_phase_Lag_3',
#  'opt_sine_phase_Lag_4',
#  'opt_sine_phase_Lag_5',
#  'opt_sine_phase_Lag_6',
#  'opt_sine_phase_Lag_7',
#  'opt_sine_phase_Lag_8',
#  'opt_sine_phase_Lag_9',
#  'opt_fourier_offset_Lag_0',
#  'opt_fourier_offset_Lag_1',
#  'opt_fourier_offset_Lag_2',
#  'opt_fourier_offset_Lag_3',
#  'opt_fourier_offset_Lag_4',
#  'opt_fourier_offset_Lag_5',
#  'opt_fourier_offset_Lag_6',
#  'opt_fourier_offset_Lag_7',
#  'opt_fourier_offset_Lag_8',
#  'opt_fourier_offset_Lag_9',
#  'opt_fourier_cosamp_Lag_0',
#  'opt_fourier_cosamp_Lag_1',
#  'opt_fourier_cosamp_Lag_2',
#  'opt_fourier_cosamp_Lag_3',
#  'opt_fourier_cosamp_Lag_4',
#  'opt_fourier_cosamp_Lag_5',
#  'opt_fourier_cosamp_Lag_6',
#  'opt_fourier_cosamp_Lag_7',
#  'opt_fourier_cosamp_Lag_8',
#  'opt_fourier_cosamp_Lag_9',
#  'opt_fourier_cosfreq_Lag_0',
#  'opt_fourier_cosfreq_Lag_1',
#  'opt_fourier_cosfreq_Lag_2',
#  'opt_fourier_cosfreq_Lag_3',
#  'opt_fourier_cosfreq_Lag_4',
#  'opt_fourier_cosfreq_Lag_5',
#  'opt_fourier_cosfreq_Lag_6',
#  'opt_fourier_cosfreq_Lag_7',
#  'opt_fourier_cosfreq_Lag_8',
#  'opt_fourier_cosfreq_Lag_9',
#  'opt_fourier_cosphase_Lag_0',
#  'opt_fourier_cosphase_Lag_1',
#  'opt_fourier_cosphase_Lag_2',
#  'opt_fourier_cosphase_Lag_3',
#  'opt_fourier_cosphase_Lag_4',
#  'opt_fourier_cosphase_Lag_5',
#  'opt_fourier_cosphase_Lag_6',
#  'opt_fourier_cosphase_Lag_7',
#  'opt_fourier_cosphase_Lag_8',
#  'opt_fourier_cosphase_Lag_9',
#  'opt_fourier_sinamp_Lag_0',
#  'opt_fourier_sinamp_Lag_1',
#  'opt_fourier_sinamp_Lag_2',
#  'opt_fourier_sinamp_Lag_3',
#  'opt_fourier_sinamp_Lag_4',
#  'opt_fourier_sinamp_Lag_5',
#  'opt_fourier_sinamp_Lag_6',
#  'opt_fourier_sinamp_Lag_7',
#  'opt_fourier_sinamp_Lag_8',
#  'opt_fourier_sinamp_Lag_9',
#  'opt_fourier_sinfreq_Lag_0',
#  'opt_fourier_sinfreq_Lag_1',
#  'opt_fourier_sinfreq_Lag_2',
#  'opt_fourier_sinfreq_Lag_3',
#  'opt_fourier_sinfreq_Lag_4',
#  'opt_fourier_sinfreq_Lag_5',
#  'opt_fourier_sinfreq_Lag_6',
#  'opt_fourier_sinfreq_Lag_7',
#  'opt_fourier_sinfreq_Lag_8',
#  'opt_fourier_sinfreq_Lag_9',
#  'opt_fourier_sinphase_Lag_0',
#  'opt_fourier_sinphase_Lag_1',
#  'opt_fourier_sinphase_Lag_2',
#  'opt_fourier_sinphase_Lag_3',
#  'opt_fourier_sinphase_Lag_4',
#  'opt_fourier_sinphase_Lag_5',
#  'opt_fourier_sinphase_Lag_6',
#  'opt_fourier_sinphase_Lag_7',
#  'opt_fourier_sinphase_Lag_8',
#  'opt_fourier_sinphase_Lag_9',
#  't_Lag_0',
#  't_Lag_1',
#  't_Lag_2',
#  't_Lag_3',
#  't_Lag_4',
#  't_Lag_5',
#  't_Lag_6',
#  't_Lag_7',
#  't_Lag_8',
#  't_Lag_9',
#  'Slopes_Lag_0',
#  'Slopes_Lag_1',
#  'Slopes_Lag_2',
#  'Slopes_Lag_3',
#  'Slopes_Lag_4',
#  'Slopes_Lag_5',
#  'Slopes_Lag_6',
#  'Slopes_Lag_7',
#  'Slopes_Lag_8',
#  'Slopes_Lag_9',
#  'autocorrelation_Lag_0',
#  'autocorrelation_Lag_1',
#  'autocorrelation_Lag_2',
#  'autocorrelation_Lag_3',
#  'autocorrelation_Lag_4',
#  'autocorrelation_Lag_5',
#  'autocorrelation_Lag_6',
#  'autocorrelation_Lag_7',
#  'autocorrelation_Lag_8',
#  'autocorrelation_Lag_9',
#  'pca_Lag_0',
#  'pca_Lag_1',
#  'pca_Lag_2',
#  'pca_Lag_3',
#  'pca_Lag_4',
#  'pca_Lag_5',
#  'pca_Lag_6',
#  'pca_Lag_7',
#  'pca_Lag_8',
#  'pca_Lag_9',
#  'ica_Lag_0',
#  'ica_Lag_1',
#  'ica_Lag_2',
#  'ica_Lag_3',
#  'ica_Lag_4',
#  'ica_Lag_5',
#  'ica_Lag_6',
#  'ica_Lag_7',
#  'ica_Lag_8',
#  'ica_Lag_9',
#  'mean_abs_Lag_0',
#  'mean_abs_Lag_1',
#  'mean_abs_Lag_2',
#  'mean_abs_Lag_3',
#  'mean_abs_Lag_4',
#  'mean_abs_Lag_5',
#  'mean_abs_Lag_6',
#  'mean_abs_Lag_7',
#  'mean_abs_Lag_8',
#  'mean_abs_Lag_9',
#  'ROC1_Lag_0',
#  'ROC1_Lag_1',
#  'ROC1_Lag_2',
#  'ROC1_Lag_3',
#  'ROC1_Lag_4',
#  'ROC1_Lag_5',
#  'ROC1_Lag_6',
#  'ROC1_Lag_7',
#  'ROC1_Lag_8',
#  'ROC1_Lag_9',
#  'ROC5_Lag_0',
#  'ROC5_Lag_1',
#  'ROC5_Lag_2',
#  'ROC5_Lag_3',
#  'ROC5_Lag_4',
#  'ROC5_Lag_5',
#  'ROC5_Lag_6',
#  'ROC5_Lag_7',
#  'ROC5_Lag_8',
#  'ROC5_Lag_9',
#  'ROC20_Lag_0',
#  'ROC20_Lag_1',
#  'ROC20_Lag_2',
#  'ROC20_Lag_3',
#  'ROC20_Lag_4',
#  'ROC20_Lag_5',
#  'ROC20_Lag_6',
#  'ROC20_Lag_7',
#  'ROC20_Lag_8',
#  'ROC20_Lag_9',
#  'WILLIAMS14_Lag_0',
#  'WILLIAMS14_Lag_1',
#  'WILLIAMS14_Lag_2',
#  'WILLIAMS14_Lag_3',
#  'WILLIAMS14_Lag_4',
#  'WILLIAMS14_Lag_5',
#  'WILLIAMS14_Lag_6',
#  'WILLIAMS14_Lag_7',
#  'WILLIAMS14_Lag_8',
#  'WILLIAMS14_Lag_9',
#  'RSI14_Lag_0',
#  'RSI14_Lag_1',
#  'RSI14_Lag_2',
#  'RSI14_Lag_3',
#  'RSI14_Lag_4',
#  'RSI14_Lag_5',
#  'RSI14_Lag_6',
#  'RSI14_Lag_7',
#  'RSI14_Lag_8',
#  'RSI14_Lag_9',
#  'CMO9_Lag_0',
#  'CMO9_Lag_1',
#  'CMO9_Lag_2',
#  'CMO9_Lag_3',
#  'CMO9_Lag_4',
#  'CMO9_Lag_5',
#  'CMO9_Lag_6',
#  'CMO9_Lag_7',
#  'CMO9_Lag_8',
#  'CMO9_Lag_9',
#  'DEMA9_Lag_0',
#  'DEMA9_Lag_1',
#  'DEMA9_Lag_2',
#  'DEMA9_Lag_3',
#  'DEMA9_Lag_4',
#  'DEMA9_Lag_5',
#  'DEMA9_Lag_6',
#  'DEMA9_Lag_7',
#  'DEMA9_Lag_8',
#  'DEMA9_Lag_9',
#  'TEMA9_Lag_0',
#  'TEMA9_Lag_1',
#  'TEMA9_Lag_2',
#  'TEMA9_Lag_3',
#  'TEMA9_Lag_4',
#  'TEMA9_Lag_5',
#  'TEMA9_Lag_6',
#  'TEMA9_Lag_7',
#  'TEMA9_Lag_8',
#  'TEMA9_Lag_9',
#  'STOCH14_Lag_0',
#  'STOCH14_Lag_1',
#  'STOCH14_Lag_2',
#  'STOCH14_Lag_3',
#  'STOCH14_Lag_4',
#  'STOCH14_Lag_5',
#  'STOCH14_Lag_6',
#  'STOCH14_Lag_7',
#  'STOCH14_Lag_8',
#  'STOCH14_Lag_9']

# %%
Y_train.head() # closing prices for the next 1-5 days
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 160      0.98883      0.99751      0.99567      0.99600      0.99112
# 217      0.98485      0.98761      0.98844      0.99046      1.00200
# 123      0.97370      0.97493      0.97203      0.97100      0.97074
# 201      1.00102      1.00397      0.99530      0.99905      0.99595
# 221      0.98790      0.98677      0.98719      0.98596      0.98485

# %% [markdown]
# ## Scale features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Reduce feature size

# %%
from sklearn.decomposition import PCA

n_components = 10
pca = PCA(n_components=n_components)

X_train_scaled_reduced = pca.fit_transform(X_train_scaled)
X_test_scaled_reduced = pca.transform(X_test_scaled)

# %% [markdown]
# ## Scale Ys

# %%
from sklearn.preprocessing import StandardScaler

scaler_y = StandardScaler()

Y_train_scaled = scaler_y.fit_transform(Y_train)
Y_test_scaled = scaler_y.transform(Y_test)

# %% [markdown]
# # 2. Train SVR

# %%
from sklearn.svm import SVR

import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
Y_train_scaled.shape
# Out:
# (198, 5)

# %%
# svrs: [svr_d1, svr_d2, svr_d3, svr_d4, svr_d5], a model for each day
svrs = []
for i in range(0, n_days_ahead):
    svr = SVR(kernel='rbf', C=1.0, gamma='scale')
    svr.fit(X_train_scaled_reduced, Y_train_scaled[:, i])
    svrs.append(svr)

# %%
pred_train = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    pred_train[f'Close_Day_{i}'] = svrs[i-1].predict(X_train_scaled_reduced)
pred_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0       0.935083     1.333525     1.231382     1.238724     1.060790
# 1       0.662151     0.712523     0.897133     1.036500     1.148289
# 2      -0.163044    -0.166527    -0.199311    -0.076068    -0.152800
# 3       1.570530     1.696651     1.200431     1.446164     1.244673
# 4       0.736652     0.798702     0.842476     0.754746     0.591802
# ..           ...          ...          ...          ...          ...
# 193    -0.354539    -0.428159    -0.316300    -0.271520    -0.387923
# 194    -1.118312    -1.320821    -1.411390    -1.572023    -1.669123
# 195     0.266869     0.150154     0.155946     0.160923     0.098947
# 196     0.875157     0.856358     0.998829     1.173311     1.218376
# 197    -0.247792    -0.225112    -0.109926    -0.081441    -0.120400
#
# [198 rows x 5 columns]

# %%
mse = mean_squared_error(Y_train_scaled, pred_train)
mse
# Out:
# 0.03465869993336697

# %%
# transform back to the original scale
Y_train_pred = scaler_y.inverse_transform(pred_train)
mse = mean_squared_error(Y_train, Y_train_pred)
mse
# Out:
# 7.403968198818928e-06

# %%
Y_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 160      0.98883      0.99751      0.99567      0.99600      0.99112
# 217      0.98485      0.98761      0.98844      0.99046      1.00200
# 123      0.97370      0.97493      0.97203      0.97100      0.97074
# 201      1.00102      1.00397      0.99530      0.99905      0.99595
# 221      0.98790      0.98677      0.98719      0.98596      0.98485
# ..           ...          ...          ...          ...          ...
# 111      0.97310      0.97037      0.97033      0.97382      0.96913
# 19       0.95925      0.95721      0.95648      0.94960      0.95030
# 97       0.98050      0.97690      0.97720      0.97920      0.97876
# 184      0.98796      0.98761      0.98946      0.99210      0.99264
# 107      0.96913      0.97130      0.97769      0.97662      0.97597
#
# [198 rows x 5 columns]

# %%
Y_train_pred
# Out:
# array([[0.9902907 , 0.99605016, 0.99429999, 0.99453457, 0.99179704],
#        [0.98630937, 0.98697145, 0.9894383 , 0.99156483, 0.99307783],
#        [0.97427203, 0.97412021, 0.97349039, 0.97522629, 0.97403279],
#        [0.99956015, 1.00135887, 0.9938498 , 0.99758091, 0.99448868],
#        [0.98739615, 0.98823135, 0.9886433 , 0.98742714, 0.98493211],
#        [0.97133377, 0.97050437, 0.96954225, 0.96917541, 0.96763046],
#        [0.98743869, 0.98751913, 0.98636651, 0.98485659, 0.984141  ],
#        [0.99758557, 0.99647628, 0.99578058, 0.99399606, 0.99035759],
#        [0.97575057, 0.97604643, 0.97711974, 0.97726824, 0.97618053],
#        [0.99451719, 0.99482054, 0.99410728, 0.99230763, 0.99274395],
#        [0.96487775, 0.96447678, 0.96295772, 0.96304756, 0.96220341],
#        [0.97460307, 0.97444788, 0.9727859 , 0.96924053, 0.96687096],
#        [0.97275342, 0.9736124 , 0.97516304, 0.97512735, 0.97479724],
#        [1.00024198, 1.00017634, 0.99956275, 1.0004658 , 0.99383648],
#        [0.97909719, 0.97878628, 0.97748135, 0.97535496, 0.97519982],
#        [0.96102484, 0.95966231, 0.95855287, 0.95974078, 0.96023656],
#        [0.99792577, 0.99966943, 0.9984424 , 0.99983192, 1.00087756],
#        [0.97961798, 0.98033544, 0.9796752 , 0.97748503, 0.97595565],
#        [0.97190541, 0.97115199, 0.97081616, 0.9706408 , 0.97005304],
#        [0.97527665, 0.97421758, 0.97311668, 0.97322749, 0.97238377],
#        [0.96451362, 0.96319545, 0.96275044, 0.96220858, 0.96014647],
#        [0.97022429, 0.96962227, 0.96977108, 0.96881045, 0.96863647],
#        [0.95778272, 0.95768247, 0.95637325, 0.95714789, 0.95849983],
#        [0.98776911, 0.98847866, 0.98766105, 0.98663686, 0.98699188],
#        [0.98667104, 0.98692806, 0.98748899, 0.98764014, 0.98733352],
#        [0.98785115, 0.98742893, 0.9873918 , 0.98954393, 0.99260299],
#        [0.95034216, 0.94908719, 0.95005807, 0.94940642, 0.94751596],
#        [0.95736563, 0.95951005, 0.96195194, 0.96292778, 0.96405885],
#        [0.97681408, 0.97617469, 0.977096  , 0.97647797, 0.9750274 ],
#        [0.98836814, 0.98861894, 0.98750248, 0.98539289, 0.98396129],
#        [0.98324494, 0.98446853, 0.98433931, 0.98584813, 0.98475459],
#        [0.97320084, 0.9733703 , 0.97315914, 0.97480276, 0.97294891],
#        [0.96180621, 0.96172646, 0.96286931, 0.96159836, 0.96246899],
#        [0.9847522 , 0.98660629, 0.98912884, 0.98928974, 0.98871026],
#        [0.96562842, 0.96386789, 0.96270046, 0.96265595, 0.96105144],
#        [0.97976733, 0.97943449, 0.97930487, 0.98092135, 0.98007069],
#        [0.98836795, 0.98845577, 0.98896845, 0.99078758, 0.98998646],
#        [0.95980022, 0.9587138 , 0.95846345, 0.95723972, 0.95724484],
#        [0.95436599, 0.95520407, 0.95484813, 0.95518412, 0.95591863],
#        [0.99294182, 0.99128038, 0.99317535, 0.99305731, 0.99257676],
#        [0.96874312, 0.96852239, 0.96857076, 0.96890147, 0.96762018],
#        [0.95865093, 0.95936129, 0.95932   , 0.95912366, 0.95895354],
#        [0.98690767, 0.98812402, 0.98857037, 0.9895529 , 0.99119741],
#        [0.96352253, 0.9608236 , 0.95927817, 0.95796921, 0.95667275],
#        [0.97506558, 0.97442695, 0.97315668, 0.97441804, 0.97335   ],
#        [0.96075784, 0.95987576, 0.95833464, 0.96023012, 0.96061141],
#        [0.99049797, 0.99022096, 0.99125652, 0.99310921, 0.99341618],
#        [0.95504047, 0.95608251, 0.9558583 , 0.95615578, 0.95664471],
#        [0.99724324, 0.99523884, 0.99448842, 0.99251646, 0.98947239]])

# %%
df_test_pred_d1 = pd.DataFrame(Y_test_pred[:,0], Y_test.index)

# %%
df_test_pred_d1 = df_test_pred_d1.sort_index()

# %%
df_test = Y_test.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_1'], marker='o')

# %%
df_test_pred_d2 = pd.DataFrame(Y_test_pred[:,1], Y_test.index)

# %%
df_test_pred_d2 = df_test_pred_d2.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_2'], marker='o')

# %% [markdown]
# # Predict next 5 days

# %%
eur_chf_feats
# Out:
#           Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0   2023-11-04         0.958614      1.000000       1.000522       -0.002749
# 1   2023-11-03         0.956503      1.000000       1.000285       -0.003062
# 2   2023-11-02         0.953924      1.002997       1.000698       -0.003977
# 3   2023-11-01         0.950673      1.000000       1.000542       -0.003011
# 4   2023-10-31         0.949086      1.000000       1.000065        0.000835
# ..         ...              ...           ...            ...             ...
# 257 2022-11-10         0.989079      1.004811       1.000410       -0.002898
# 258 2022-11-09         0.987864      1.000000       1.000053        0.000609
# 259 2022-11-08         0.987886      1.000000       0.999939        0.000463
# 260 2022-11-07         0.988222      1.000000       0.999933        0.001346
# 261 2022-11-04         0.988480      1.000000       0.999969       -0.001034
#
#      opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0              0.957463            0.052632             0.938212
# 1              0.957482            0.001027             1.193877
# 2              0.957282           -0.068468             1.020909
# 3              0.957335            0.068881             1.054420
# 4              0.957217            0.093351             1.117052
# ..                  ...                 ...                  ...
# 257            0.982069            0.040914             1.087436
# 258            0.981916            0.011671             1.050313
# 259            0.981422           -0.181783             0.906054
# 260            0.981012            0.148192             1.049125
# 261            0.980695           -0.142938             1.038504
#
#      opt_fourier_cosphase  opt_fourier_sinamp  ...       ROC1       ROC5  \
# 0               -0.001767            0.052491  ... -14.041234 -45.814813
# 1               -1.520623           -0.000813  ... -17.715717 -45.248288
# 2               -0.487678           -0.068968  ...  26.257384 -38.147481
# 3               -2.563270           -0.068181  ... -25.509741 -53.055586
# 4               -2.027260            0.094565  ... -18.545095 -26.839844
# ..                    ...                 ...  ...        ...        ...
# 257             -0.322856            0.040638  ... -44.625517  11.796658
# 258              0.068952            0.010748  ...  11.529607  44.685786
# 259              2.878329           -0.182054  ...  12.034612   5.675777
# 260             -3.088017           -0.149474  ...  11.544606 -16.817884
# 261             -0.563259           -0.143959  ...  44.853226   8.338141
#
#           ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0    -21.733902 -4268.541269  60.493388  29.135814 -0.015573 -0.012660
# 1      4.763255 -4277.711575  58.312440  23.856903 -0.017820 -0.014858
# 2     33.001729 -4615.126767  54.756242  15.132448 -0.019971 -0.016985
# 3     13.928513 -4670.439535  60.369975  30.989510 -0.021409 -0.018125
# 4     30.001445 -4758.584347  54.751880  17.681247 -0.025344 -0.022992
# ..          ...          ...        ...        ...       ...       ...
# 257 -200.210303 -7213.128295  51.540758  -2.208123  0.012803  0.011631
# 258 -270.469936 -7059.120682  63.730768  28.834766  0.014576  0.014158
# 259 -320.742303 -6754.411223  61.786640  23.791071  0.013488  0.012715
# 260 -239.482073 -5928.322984  59.928391  18.976003  0.012725  0.011638
# 261 -244.256654 -5598.441130  58.309414  14.809934  0.012362  0.011067
#
#        STOCH14    Close
# 0    60.493388  0.96398
# 1    58.312440  0.96188
# 2    54.756242  0.95866
# 3    60.369975  0.96244
# 4    54.751880  0.95751
# ..         ...      ...
# 257  51.540758  0.98546
# 258  63.730768  0.99241
# 259  61.786640  0.99080
# 260  59.928391  0.98930
# 261  58.309414  0.98801
#
# [262 rows x 28 columns]

# %%
def prepare_for_pred(df: pd.DataFrame, n_lag_features: int = 10):
    df = df.copy()
    df.drop(['t'], axis=1)
    X = []
    
    for col in df.columns:
        if col == 'Date':
            X.append(df[col])
        elif col != 'Close':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            X.append(col_lag_features)
        
    df = pd.concat(X, axis=1)
    df.dropna(inplace=True)
    return df

# %%
input_feats = prepare_for_pred(eur_chf_feats, n_lag_features).iloc[[0]]
input_feats
# Out:
#         Date  opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  \
# 0 2023-11-04               0.958614               0.956503
#
#    opt_sine_offset_Lag_2  opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  \
# 0               0.953924               0.950673               0.949086
#
#    opt_sine_offset_Lag_5  opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  \
# 0               0.948062               0.946643               0.946777
#
#    opt_sine_offset_Lag_8  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.947573  ...      60.493388       58.31244      54.756242
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      60.369975       54.75188       48.72816      42.976766      39.333112
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      37.022508      41.948383
#
# [1 rows x 261 columns]

# %%
input_feats = input_feats.drop(columns=['Date'])
input_feats
# Out:
#    opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 0               0.958614               0.956503               0.953924
#
#    opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 0               0.950673               0.949086               0.948062
#
#    opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 0               0.946643               0.946777               0.947573
#
#    opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.947763  ...      60.493388       58.31244      54.756242
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      60.369975       54.75188       48.72816      42.976766      39.333112
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      37.022508      41.948383
#
# [1 rows x 260 columns]

# %%
input_feats_scaled = scaler.transform(input_feats)

# %%
input_feats_scaled_reduced = pca.transform(input_feats_scaled)

# %%
preds_scaled = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    preds_scaled[f'Close_Day_{i}'] = svrs[i-1].predict(input_feats_scaled_reduced)
preds_scaled
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0      -0.7259    -0.757058     -0.86066    -0.895488    -0.929419

# %%
preds_unscaled = scaler_y.inverse_transform(preds_scaled)

# %%
pd.DataFrame(preds_unscaled, columns=preds_scaled.columns)
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0     0.966062     0.965487     0.963871     0.963193     0.962665

# %%
outfile = 'predictions_T_svr.csv'

# Save the NumPy matrix to the CSV file (append mode)
with open(outfile, 'a') as f:
    np.savetxt(f, preds_unscaled, delimiter=',')
