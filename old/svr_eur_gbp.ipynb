# %% [markdown]
# # Load Data

# %%
import os
import sys

feat_dir = os.path.join('..', 'ML_Forex_Forecasting')
sys.path.append(feat_dir)

# %%
import pandas as pd
from generate_features import generate_features

# %%
usd_eur = pd.read_csv(os.path.join(feat_dir, "./USDEUR=X.csv"), parse_dates=['Date'])
eur_chf = pd.read_csv(os.path.join(feat_dir, "./EURCHF=X.csv"), parse_dates=['Date'])
eur_gbp = pd.read_csv(os.path.join(feat_dir, "./EURGBP=X.csv"), parse_dates=['Date'])
gbp_chf = pd.read_csv(os.path.join(feat_dir, "./GBPCHF=X.csv"), parse_dates=['Date'])
usd_chf = pd.read_csv(os.path.join(feat_dir, "./USDCHF=X.csv"), parse_dates=['Date'])
usd_gbp = pd.read_csv(os.path.join(feat_dir, "./USDGBP=X.csv"), parse_dates=['Date'])

# %%
data = eur_gbp

# %%
feats = generate_features(data)
print(f"EUR/CHF Features shape: {feats.shape}")
display(feats.head())
# Out:
# EUR/CHF Features shape: (262, 28)
#         Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0 2023-11-04         0.870904      1.000000       1.000037       -0.000015
# 1 2023-11-03         0.870947      1.000000       0.999947       -0.000017
# 2 2023-11-02         0.871637      0.996344       0.999789        0.001560
# 3 2023-11-01         0.871884      0.989384       1.000117       -0.001315
# 4 2023-10-31         0.871353      1.000000       1.000087        0.000039
#
#    opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0            0.867808           -0.000526             1.301513
# 1            0.867811           -0.015800             1.020890
# 2            0.867625            0.772528             1.061765
# 3            0.867384            2.653029             0.870333
# 4            0.867143           -0.098707             1.040771
#
#    opt_fourier_cosphase  opt_fourier_sinamp  ...         ROC1        ROC5  \
# 0             -1.361042           -0.000543  ... -1453.991975 -348.869503
# 1              1.711873           -0.015565  ...  -116.465040 -341.141141
# 2             -2.182285           -0.772383  ...  -937.812560 -161.958133
# 3             -2.006040           -2.653532  ...   -90.210953  -69.978798
# 4              0.414727           -0.099181  ...    36.114855  390.145618
#
#         ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0  -41.157688 -9529.994883  47.994844 -11.584598 -0.000661 -0.001663
# 1 -104.869782 -7160.110705  56.730784  11.865286  0.000709  0.000153
# 2  -68.494154 -7174.840656  52.854249   0.285988  0.000739  0.000157
# 3 -104.860241 -7160.683537  57.447552  13.144303  0.001656  0.001500
# 4 -149.912800 -6661.598232  62.395395  27.615052  0.002024  0.002197
#
#      STOCH14    Close
# 0  47.994844  0.86707
# 1  56.730784  0.87077
# 2  52.854249  0.86897
# 3  57.447552  0.87070
# 4  62.395395  0.87240
#
# [5 rows x 28 columns]

# %%
feats.columns
# Out:
# Index(['Date', 'opt_sine_offset', 'opt_sine_amp', 'opt_sine_freq',
#        'opt_sine_phase', 'opt_fourier_offset', 'opt_fourier_cosamp',
#        'opt_fourier_cosfreq', 'opt_fourier_cosphase', 'opt_fourier_sinamp',
#        'opt_fourier_sinfreq', 'opt_fourier_sinphase', 't', 'Slopes',
#        'autocorrelation', 'pca', 'ica', 'mean_abs', 'ROC1', 'ROC5', 'ROC20',
#        'WILLIAMS14', 'RSI14', 'CMO9', 'DEMA9', 'TEMA9', 'STOCH14', 'Close'],
#       dtype='object')

# %% [markdown]
# # 1. Prepare X_train, Y_train, X_test, Y_test

# %%
from sklearn.model_selection import train_test_split

# %%
# use the past 20 days to train the model
def prepare_train_test(df: pd.DataFrame, n_lag_features: int = 10, test_size: float = 0.2, n_days_ahead: int = 5):
    df = df.copy()
    df.drop(['t'], axis=1)
    XY = []
    
    for col in df.columns:
        if col == 'Close':
            closes = pd.DataFrame()
            for i in range(1, n_days_ahead + 1):
                lag_feature_name = f'{col}_Day_{i}'
                closes[lag_feature_name] = df[col].shift(i)
            XY.append(closes)
        elif col != 'Date':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            XY.append(col_lag_features)
    df = pd.concat(XY, axis=1)
    df.dropna(inplace=True)
    
    Y_columns = [f'{col}_Day_{i}' for i in range(1, n_days_ahead + 1)]
    Y = df[Y_columns]
    X = df.drop(columns=Y_columns, axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
n_days_ahead = 5 # predict the next 5 days
n_lag_features = 10 # how many past days used for predictions

# %%
X_train, X_test, Y_train, Y_test = prepare_train_test(feats, n_lag_features=n_lag_features, n_days_ahead=n_days_ahead)

# %%
X_train.head()
# Out:
#      opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 160               0.879416               0.878380               0.876333
# 217               0.883735               0.884194               0.883431
# 123               0.870103               0.870662               0.870873
# 201               0.878323               0.876892               0.875938
# 221               0.881541               0.880409               0.877997
#
#      opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 160               0.876893               0.878736               0.880008
# 217               0.882200               0.881541               0.880409
# 123               0.871471               0.873863               0.876622
# 201               0.877615               0.879978               0.882593
# 221               0.876309               0.874813               0.872737
#
#      opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 160               0.882702               0.885105               0.887077
# 217               0.877997               0.876309               0.874813
# 123               0.878217               0.879005               0.880113
# 201               0.885440               0.885873               0.884946
# 221               0.869906               0.866711               0.864612
#
#      opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 160               0.888676  ...      46.667057      49.437645      53.259451
# 217               0.872737  ...      56.964067      59.325590      66.989240
# 123               0.881113  ...      39.961835      35.447753      39.899839
# 201               0.883443  ...      48.437311      51.557855      55.597520
# 221               0.861549  ...      65.988640      65.588923      66.777080
#
#      STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  \
# 160      48.494055      37.061336      40.152913      40.313876
# 217      66.053261      65.988640      65.588923      66.777080
# 123      40.600839      36.053976      33.261092      36.928148
# 201      49.844075      46.525012      44.323663      44.660750
# 221      63.349276      62.381267      64.107945      62.534336
#
#      STOCH14_Lag_7  STOCH14_Lag_8  STOCH14_Lag_9
# 160      40.646746      47.410060      45.175079
# 217      63.349276      62.381267      64.107945
# 123      37.575052      42.195892      48.855015
# 201      48.856645      61.510527      59.517311
# 221      56.509128      58.317058      56.035986
#
# [5 rows x 260 columns]

# %%
Y_train.head() # closing prices for the next 1-5 days
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 160      0.87874      0.87901      0.88064      0.88024      0.87916
# 217      0.88324      0.87944      0.88065      0.88348      0.88529
# 123      0.86821      0.86807      0.86848      0.86935      0.86727
# 201      0.87666      0.87851      0.88232      0.88900      0.89206
# 221      0.88414      0.88511      0.88089      0.87947      0.88324

# %% [markdown]
# ## Scale features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Reduce feature size

# %%
from sklearn.decomposition import PCA

n_components = 10
pca = PCA(n_components=n_components)

X_train_scaled_reduced = pca.fit_transform(X_train_scaled)
X_test_scaled_reduced = pca.transform(X_test_scaled)

# %% [markdown]
# ## Scale Ys

# %%
from sklearn.preprocessing import StandardScaler

scaler_y = StandardScaler()

Y_train_scaled = scaler_y.fit_transform(Y_train)
Y_test_scaled = scaler_y.transform(Y_test)

# %% [markdown]
# # 2. Train SVR

# %%
from sklearn.svm import SVR

import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
Y_train_scaled.shape
# Out:
# (198, 5)

# %%
# svrs: [svr_d1, svr_d2, svr_d3, svr_d4, svr_d5], a model for each day
svrs = []
for i in range(0, n_days_ahead):
    svr = SVR(kernel='rbf', C=1.0, gamma='scale')
    svr.fit(X_train_scaled_reduced, Y_train_scaled[:, i])
    svrs.append(svr)

# %%
pred_train = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    pred_train[f'Close_Day_{i}'] = svrs[i-1].predict(X_train_scaled_reduced)
pred_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0       0.940076     0.965155     1.045997     1.047738     0.974859
# 1       1.027082     0.930510     0.846464     1.058074     1.253199
# 2      -0.066626    -0.090916    -0.054430     0.028838    -0.159245
# 3       0.689673     0.724419     0.997678     1.127519     1.067090
# 4       1.044269     1.137428     0.875627     0.766751     1.069636
# ..           ...          ...          ...          ...          ...
# 193    -0.812870    -0.838980    -0.957785    -0.983441    -1.158777
# 194    -0.548869    -0.592745    -0.455454    -0.449634    -0.442744
# 195    -1.240326    -1.114075    -1.028841    -1.046803    -0.960860
# 196     0.952985     1.004784     1.108421     1.062474     0.937930
# 197    -0.947364    -1.110402    -1.053215    -1.171742    -1.225996
#
# [198 rows x 5 columns]

# %%
mse = mean_squared_error(Y_train_scaled, pred_train)
mse
# Out:
# 0.06678574237252115

# %%
# transform back to the original scale
Y_train_pred = scaler_y.inverse_transform(pred_train)
mse = mean_squared_error(Y_train, Y_train_pred)
mse
# Out:
# 8.240027031273559e-06

# %%
Y_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
#
#        [0.86513776, 0.86500286, 0.86312715, 0.86331145, 0.86362796],
#        [0.8597075 , 0.86091361, 0.8611641 , 0.86244631, 0.86215432],
#        [0.87474628, 0.87429078, 0.87498344, 0.87518002, 0.87448919],
#        [0.87231629, 0.87457747, 0.8723959 , 0.87289327, 0.87456322],
#        [0.87716257, 0.87790756, 0.88041815, 0.88065914, 0.87937358],
#        [0.86404108, 0.86419281, 0.86457822, 0.8651595 , 0.866678  ],
#        [0.8593601 , 0.86103493, 0.8606825 , 0.86045916, 0.86129174],
#        [0.85496656, 0.85570065, 0.85613976, 0.85636732, 0.85839987],
#        [0.88403145, 0.88524481, 0.88402958, 0.88262763, 0.88372724],
#        [0.86452312, 0.8656133 , 0.86865905, 0.86771284, 0.86556828],
#        [0.87055185, 0.86997274, 0.86947425, 0.87026826, 0.86937057],
#        [0.86753777, 0.86712463, 0.86671811, 0.86584098, 0.86537571],
#        [0.866544  , 0.86802999, 0.86987249, 0.86916108, 0.8672512 ],
#        [0.86635586, 0.86593048, 0.86541476, 0.86504143, 0.86396631],
#        [0.88243625, 0.88076657, 0.88038489, 0.87851035, 0.87883828],
#        [0.87591957, 0.87609669, 0.87831984, 0.8782841 , 0.87799212],
#        [0.86147174, 0.86120527, 0.86130507, 0.8608882 , 0.8606652 ],
#        [0.85954476, 0.8600178 , 0.86166306, 0.86282974, 0.86268405],
#        [0.88243782, 0.88241796, 0.88147768, 0.88270424, 0.88527251],
#        [0.87026538, 0.87083352, 0.87114631, 0.87084258, 0.87054661],
#        [0.86053067, 0.86136987, 0.86105299, 0.8607554 , 0.85992488],
#        [0.88075251, 0.88107191, 0.88199329, 0.88363661, 0.88494532],
#        [0.8655814 , 0.86491075, 0.8654787 , 0.86410802, 0.86406674],
#        [0.86984132, 0.8706578 , 0.87107608, 0.87260161, 0.87107003],
#        [0.86223221, 0.86132229, 0.86186244, 0.86283224, 0.86173251],
#        [0.88465641, 0.88494692, 0.88098949, 0.88158092, 0.88127665],
#        [0.85448418, 0.85628533, 0.85639976, 0.85773275, 0.85814555],
#        [0.88335538, 0.88595276, 0.88541118, 0.88567755, 0.8864944 ]])

# %%
df_test_pred_d1 = pd.DataFrame(Y_test_pred[:,0], Y_test.index)

# %%
df_test_pred_d1 = df_test_pred_d1.sort_index()

# %%
df_test = Y_test.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_1'], marker='o')

# %%
df_test_pred_d2 = pd.DataFrame(Y_test_pred[:,1], Y_test.index)

# %%
df_test_pred_d2 = df_test_pred_d2.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_2'], marker='o')

# %% [markdown]
# # Predict next 5 days

# %%
feats
# Out:
#           Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0   2023-11-04         0.870904      1.000000       1.000037       -0.000015
# 1   2023-11-03         0.870947      1.000000       0.999947       -0.000017
# 2   2023-11-02         0.871637      0.996344       0.999789        0.001560
# 3   2023-11-01         0.871884      0.989384       1.000117       -0.001315
# 4   2023-10-31         0.871353      1.000000       1.000087        0.000039
# ..         ...              ...           ...            ...             ...
# 257 2022-11-10         0.870689      1.003614       1.000775       -0.005412
# 258 2022-11-09         0.868165      1.008128       1.000185       -0.001941
# 259 2022-11-08         0.866421      1.008049       1.000476       -0.002746
# 260 2022-11-07         0.862762      1.179504       1.000778       -0.004185
# 261 2022-11-04         0.860463      1.000000       0.999960        0.001665
#
#      opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0              0.867808           -0.000526             1.301513
# 1              0.867811           -0.015800             1.020890
# 2              0.867625            0.772528             1.061765
# 3              0.867384            2.653029             0.870333
# 4              0.867143           -0.098707             1.040771
# ..                  ...                 ...                  ...
# 257            0.874682           -1.581326             1.019214
# 258            0.874790           -1.610089             0.986844
# 259            0.874477           -1.536818             0.926602
# 260            0.873898            4.787608             1.070146
# 261            0.874465            1.694811             1.007597
#
#      opt_fourier_cosphase  opt_fourier_sinamp  ...         ROC1        ROC5  \
# 0               -1.361042           -0.000543  ... -1453.991975 -348.869503
# 1                1.711873           -0.015565  ...  -116.465040 -341.141141
# 2               -2.182285           -0.772383  ...  -937.812560 -161.958133
# 3               -2.006040           -2.653532  ...   -90.210953  -69.978798
# 4                0.414727           -0.099181  ...    36.114855  390.145618
# ..                    ...                 ...  ...          ...         ...
# 257              0.193747           -1.579860  ...   435.349845 -223.173287
# 258              0.165342            1.608514  ...  -377.655909 -118.574216
# 259              0.247811           -1.535539  ...  -112.899490  -91.378697
# 260             -3.465122           -4.788463  ...   159.854240 -146.538900
# 261             -3.385062           -1.695891  ...  -124.721202 -124.749470
#
#           ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0    -41.157688 -9529.994883  47.994844 -11.584598 -0.000661 -0.001663
# 1   -104.869782 -7160.110705  56.730784  11.865286  0.000709  0.000153
# 2    -68.494154 -7174.840656  52.854249   0.285988  0.000739  0.000157
# 3   -104.860241 -7160.683537  57.447552  13.144303  0.001656  0.001500
# 4   -149.912800 -6661.598232  62.395395  27.615052  0.002024  0.002197
# ..          ...          ...        ...        ...       ...       ...
# 257  200.866413 -3501.951480  55.815104  18.412148  0.003664  0.007305
# 258  -85.449269 -3537.200676  51.124727   5.037130 -0.000556  0.002213
# 259 -111.963584 -4055.350522  49.571716   0.448199 -0.002047  0.000771
# 260  -94.815413 -4026.074358  53.210183  11.707334 -0.002751  0.000443
# 261  -66.203742 -4121.756953  51.405550   6.571798 -0.006919 -0.005028
#
#        STOCH14    Close
# 0    47.994844  0.86707
# 1    56.730784  0.87077
# 2    52.854249  0.86897
# 3    57.447552  0.87070
# 4    62.395395  0.87240
# ..         ...      ...
# 257  55.815104  0.88130
# 258  51.124727  0.87253
# 259  49.571716  0.86979
# 260  53.210183  0.87614
# 261  51.405550  0.87268
#
# [262 rows x 28 columns]

# %%
def prepare_for_pred(df: pd.DataFrame, n_lag_features: int = 10):
    df = df.copy()
    df.drop(['t'], axis=1)
    X = []
    
    for col in df.columns:
        if col == 'Date':
            X.append(df[col])
        elif col != 'Close':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            X.append(col_lag_features)
        
    df = pd.concat(X, axis=1)
    df.dropna(inplace=True)
    return df

# %%
input_feats = prepare_for_pred(feats, n_lag_features).iloc[[0]]
input_feats
# Out:
#         Date  opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  \
# 0 2023-11-04               0.870904               0.870947
#
#    opt_sine_offset_Lag_2  opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  \
# 0               0.871637               0.871884               0.871353
#
#    opt_sine_offset_Lag_5  opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  \
# 0               0.871324               0.871417               0.870662
#
#    opt_sine_offset_Lag_8  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.869772  ...      47.994844      56.730784      52.854249
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      57.447552      62.395395      61.489538      58.739189      66.426068
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      63.191878      62.784618
#
# [1 rows x 261 columns]

# %%
input_feats = input_feats.drop(columns=['Date'])
input_feats
# Out:
#    opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 0               0.870904               0.870947               0.871637
#
#    opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 0               0.871884               0.871353               0.871324
#
#    opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 0               0.871417               0.870662               0.869772
#
#    opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.868797  ...      47.994844      56.730784      52.854249
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      57.447552      62.395395      61.489538      58.739189      66.426068
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      63.191878      62.784618
#
# [1 rows x 260 columns]

# %%
input_feats_scaled = scaler.transform(input_feats)

# %%
input_feats_scaled_reduced = pca.transform(input_feats_scaled)

# %%
preds_scaled = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    preds_scaled[f'Close_Day_{i}'] = svrs[i-1].predict(input_feats_scaled_reduced)
preds_scaled
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0    -0.236034    -0.350321      -0.2488    -0.352755    -0.425951

# %%
preds_unscaled = scaler_y.inverse_transform(preds_scaled)

# %%
pd.DataFrame(preds_unscaled, columns=preds_scaled.columns)
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0      0.86744     0.866301     0.867442     0.866234     0.865444

# %%
outfile = 'predictions_T_svr.csv'

# Save the NumPy matrix to the CSV file (append mode)
with open(outfile, 'a') as f:
    np.savetxt(f, preds_unscaled, delimiter=',')
