# %% [markdown]
# # Load Data

# %%
import os
import sys

feat_dir = os.path.join('..', 'ML_Forex_Forecasting')
sys.path.append(feat_dir)

# %%
import pandas as pd
from generate_features import generate_features

# %%
usd_eur = pd.read_csv(os.path.join(feat_dir, "./USDEUR=X.csv"), parse_dates=['Date'])
eur_chf = pd.read_csv(os.path.join(feat_dir, "./EURCHF=X.csv"), parse_dates=['Date'])
eur_gbp = pd.read_csv(os.path.join(feat_dir, "./EURGBP=X.csv"), parse_dates=['Date'])
gbp_chf = pd.read_csv(os.path.join(feat_dir, "./GBPCHF=X.csv"), parse_dates=['Date'])
usd_chf = pd.read_csv(os.path.join(feat_dir, "./USDCHF=X.csv"), parse_dates=['Date'])
usd_gbp = pd.read_csv(os.path.join(feat_dir, "./USDGBP=X.csv"), parse_dates=['Date'])

# %%
data = usd_gbp

# %%
feats = generate_features(data)
print(f"EUR/CHF Features shape: {feats.shape}")
display(feats.head())
# Out:
# /usr/local/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1600.
#   warnings.warn(errors[info][0], RuntimeWarning)
# EUR/CHF Features shape: (261, 28)
#         Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0 2023-11-03         0.823231      1.000000       0.999889       -0.000276
# 1 2023-11-02         0.823912      1.000000       0.999851        0.001898
# 2 2023-11-01         0.824287      1.000000       1.000006       -0.001609
# 3 2023-10-31         0.822878      1.012431       1.000526       -0.003502
# 4 2023-10-30         0.822007      1.000000       0.999801        0.001999
#
#    opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0            0.821073           -0.166832             0.808415
# 1            0.820840           -0.235751             0.971239
# 2            0.820350           -0.420754             0.734517
# 3            0.819682           -0.204354             0.902361
# 4            0.819226            0.288756             1.077513
#
#    opt_fourier_cosphase  opt_fourier_sinamp  ...       ROC1         ROC5  \
# 0              1.355945           -0.166235  ... -13.417576   -46.868713
# 1              0.675654           -0.236676  ... -29.529883   -52.433173
# 2              0.905955           -0.421449  ...  15.450779    10.620508
# 3              3.675128           -0.203644  ... -37.219043  1993.725383
# 4             -5.749885           -0.289510  ...  20.140879    56.137304
#
#         ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0   -6.257833 -4048.504950  51.687019  -2.674181  0.005986  0.005147
# 1  -38.479160 -5606.709379  52.602051  -0.170413  0.006857  0.006257
# 2  -42.204763 -5592.890455  55.448772   7.610794  0.007728  0.007481
# 3  -45.988930 -4702.776488  54.410492   4.577080  0.007893  0.007798
# 4  130.517454 -4590.726501  59.337534  17.951895  0.008548  0.008914
#
#      STOCH14    Close
# 0  51.687019  0.82022
# 1  52.602051  0.82087
# 2  55.448772  0.82290
# 3  54.410492  0.82198
# 4  59.337534  0.82551
#
# [5 rows x 28 columns]

# %%
feats.columns
# Out:
# Index(['Date', 'opt_sine_offset', 'opt_sine_amp', 'opt_sine_freq',
#        'opt_sine_phase', 'opt_fourier_offset', 'opt_fourier_cosamp',
#        'opt_fourier_cosfreq', 'opt_fourier_cosphase', 'opt_fourier_sinamp',
#        'opt_fourier_sinfreq', 'opt_fourier_sinphase', 't', 'Slopes',
#        'autocorrelation', 'pca', 'ica', 'mean_abs', 'ROC1', 'ROC5', 'ROC20',
#        'WILLIAMS14', 'RSI14', 'CMO9', 'DEMA9', 'TEMA9', 'STOCH14', 'Close'],
#       dtype='object')

# %% [markdown]
# # 1. Prepare X_train, Y_train, X_test, Y_test

# %%
from sklearn.model_selection import train_test_split

# %%
# use the past 20 days to train the model
def prepare_train_test(df: pd.DataFrame, n_lag_features: int = 10, test_size: float = 0.2, n_days_ahead: int = 5):
    df = df.copy()
    df.drop(['t'], axis=1)
    XY = []
    
    for col in df.columns:
        if col == 'Close':
            closes = pd.DataFrame()
            for i in range(1, n_days_ahead + 1):
                lag_feature_name = f'{col}_Day_{i}'
                closes[lag_feature_name] = df[col].shift(i)
            XY.append(closes)
        elif col != 'Date':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            XY.append(col_lag_features)
    df = pd.concat(XY, axis=1)
    df.dropna(inplace=True)
    
    Y_columns = [f'{col}_Day_{i}' for i in range(1, n_days_ahead + 1)]
    Y = df[Y_columns]
    X = df.drop(columns=Y_columns, axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
n_days_ahead = 5 # predict the next 5 days
n_lag_features = 10 # how many past days used for predictions

# %%
X_train, X_test, Y_train, Y_test = prepare_train_test(feats, n_lag_features=n_lag_features, n_days_ahead=n_days_ahead)

# %%
X_train.head()
# Out:
#      opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 159               0.816019               0.818733               0.821251
# 216               0.829918               0.829083               0.829212
# 123               0.795887               0.793419               0.792542
# 200               0.807663               0.808163               0.808757
# 245               0.839988               0.842373               0.841867
#
#      opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 159               0.822797               0.823932               0.825286
# 216               0.829734               0.830067               0.829295
# 123               0.793461               0.795010               0.797090
# 200               0.811071               0.813720               0.815892
# 245               0.843127               0.844602               0.846504
#
#      opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 159               0.827507               0.830859               0.835569
# 216               0.827378               0.826076               0.824923
# 123               0.797883               0.798902               0.800208
# 200               0.818458               0.820132               0.820467
# 245               0.854624               0.860376               0.866004
#
#      opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 159               0.838260  ...      42.599578      40.142115      40.223320
# 216               0.822556  ...      49.859592      55.315980      49.886883
# 123               0.800632  ...      46.717828      52.373561      47.853938
# 200               0.821864  ...      36.462680      36.592900      40.668897
# 245               0.870592  ...      32.627623      33.573894      38.278904
#
#      STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  \
# 159      42.653703      39.472295      43.349127      47.147889
# 216      46.187707      50.007936      51.750215      51.820067
# 123      36.352604      36.497613      37.205544      35.469899
# 200      36.684217      34.550937      35.090338      36.969243
# 245      40.281379      37.620441      38.326062      35.988449
#
#      STOCH14_Lag_7  STOCH14_Lag_8  STOCH14_Lag_9
# 159      49.311467      44.580053      43.452320
# 216      48.676005      49.958923      51.000701
# 123      38.060291      38.867892      44.549282
# 200      39.719467      43.427810      42.187005
# 245      36.805539      39.942114      38.145656
#
# [5 rows x 260 columns]

# %%
Y_train.head() # closing prices for the next 1-5 days
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 159     0.813170     0.811000      0.81211     0.807280      0.81387
# 216     0.839470     0.825330      0.82069     0.822740      0.82240
# 123     0.801000     0.801102      0.80565     0.802500      0.80422
# 200     0.806432     0.809480      0.81242     0.807100      0.81813
# 245     0.829550     0.836100      0.83704     0.827986      0.81571

# %% [markdown]
# ## Scale features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Reduce feature size

# %%
from sklearn.decomposition import PCA

n_components = 10
pca = PCA(n_components=n_components)

X_train_scaled_reduced = pca.fit_transform(X_train_scaled)
X_test_scaled_reduced = pca.transform(X_test_scaled)

# %% [markdown]
# ## Scale Ys

# %%
from sklearn.preprocessing import StandardScaler

scaler_y = StandardScaler()

Y_train_scaled = scaler_y.fit_transform(Y_train)
Y_test_scaled = scaler_y.transform(Y_test)

# %% [markdown]
# # 2. Train SVR

# %%
from sklearn.svm import SVR

import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
Y_train_scaled.shape
# Out:
# (197, 5)

# %%
# svrs: [svr_d1, svr_d2, svr_d3, svr_d4, svr_d5], a model for each day
svrs = []
for i in range(0, n_days_ahead):
    svr = SVR(kernel='rbf', C=1.0, gamma='scale')
    svr.fit(X_train_scaled_reduced, Y_train_scaled[:, i])
    svrs.append(svr)

# %%
pred_train = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    pred_train[f'Close_Day_{i}'] = svrs[i-1].predict(X_train_scaled_reduced)
pred_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0       0.184975     0.078234    -0.078441    -0.105332    -0.105411
# 1       1.062499     0.933418     0.916331     0.961122     0.986511
# 2      -0.410249    -0.424193    -0.453644    -0.575305    -0.680794
# 3       0.088139     0.170817     0.357320     0.465588     0.605632
# 4       1.148536     1.526685     1.562706     1.090598     0.415314
# ..           ...          ...          ...          ...          ...
# 192     0.009304    -0.015676    -0.023194    -0.128414    -0.199469
# 193     0.720918     0.812505     0.872241     0.891033     0.814941
# 194    -1.395844    -1.318983    -1.258673    -1.205038    -1.106680
# 195     1.399421     1.242135     1.197445     1.318367     1.547244
# 196    -0.274518    -0.406630    -0.541895    -0.623577    -0.691134
#
# [197 rows x 5 columns]

# %%
mse = mean_squared_error(Y_train_scaled, pred_train)
mse
# Out:
# 0.05715017831330656

# %%
# transform back to the original scale
Y_train_pred = scaler_y.inverse_transform(pred_train)
mse = mean_squared_error(Y_train, Y_train_pred)
mse
# Out:
# 1.8700722015068813e-05

# %%
Y_train
# Out:
#      Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
#
#        [0.82083763, 0.82119644, 0.82244365, 0.82449657, 0.82156554],
#        [0.80284668, 0.80148538, 0.80134296, 0.80041821, 0.79957838],
#        [0.78376698, 0.78502075, 0.7835143 , 0.78449451, 0.78217929],
#        [0.82240197, 0.82379083, 0.82903005, 0.82875408, 0.82897263],
#        [0.81007217, 0.8092708 , 0.80925837, 0.80656564, 0.8024818 ],
#        [0.80812013, 0.80837516, 0.81149783, 0.81211453, 0.81203479],
#        [0.8199842 , 0.82136162, 0.82122157, 0.82024183, 0.82215556],
#        [0.80656126, 0.80865031, 0.81084349, 0.81264624, 0.81558095],
#        [0.78789264, 0.78447388, 0.78160646, 0.78292775, 0.78462193],
#        [0.81671471, 0.81310634, 0.8167536 , 0.8181657 , 0.81772209],
#        [0.81877622, 0.81718249, 0.81633529, 0.81819289, 0.81739756],
#        [0.80128395, 0.80083272, 0.80041687, 0.79817101, 0.79656158],
#        [0.81609037, 0.81695912, 0.81887899, 0.82144107, 0.82384118],
#        [0.81486378, 0.81466316, 0.81432631, 0.81559541, 0.81354312],
#        [0.82118898, 0.82090959, 0.82182445, 0.8237023 , 0.82079266],
#        [0.8019219 , 0.79975709, 0.79874771, 0.79811001, 0.79766497],
#        [0.80721719, 0.80746502, 0.81070099, 0.81207947, 0.81268151],
#        [0.7873708 , 0.78641855, 0.78576457, 0.78561821, 0.7848875 ],
#        [0.78763387, 0.78708503, 0.78590301, 0.78793585, 0.78944951],
#        [0.82852773, 0.82773873, 0.82678265, 0.82737825, 0.82747511],
#        [0.80609295, 0.80561312, 0.80585731, 0.8046358 , 0.80410394],
#        [0.78856514, 0.78768217, 0.787186  , 0.78804426, 0.78636676],
#        [0.82983405, 0.82920507, 0.82960197, 0.83125142, 0.83155381],
#        [0.82035236, 0.82057282, 0.8205635 , 0.8215499 , 0.81905043],
#        [0.79557612, 0.79465899, 0.79339286, 0.79227568, 0.79174062],
#        [0.78471365, 0.78601549, 0.78372326, 0.78543284, 0.78379544],
#        [0.83038781, 0.82632956, 0.82812783, 0.83013677, 0.82932296],
#        [0.7927571 , 0.79443928, 0.79617319, 0.79820808, 0.79889831],
#        [0.81486378, 0.81466316, 0.81432631, 0.81559541, 0.81354312]])

# %%
df_test_pred_d1 = pd.DataFrame(Y_test_pred[:,0], Y_test.index)

# %%
df_test_pred_d1 = df_test_pred_d1.sort_index()

# %%
df_test = Y_test.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_1'], marker='o')

# %%
df_test_pred_d2 = pd.DataFrame(Y_test_pred[:,1], Y_test.index)

# %%
df_test_pred_d2 = df_test_pred_d2.sort_index()

# %%
import matplotlib.pyplot as plt
plt.plot(df_test_pred_d1, marker='o')
plt.plot(df_test['Close_Day_2'], marker='o')

# %% [markdown]
# # Predict next 5 days

# %%
feats
# Out:
#           Date  opt_sine_offset  opt_sine_amp  opt_sine_freq  opt_sine_phase  \
# 0   2023-11-03         0.823231      1.000000       0.999889       -0.000276
# 1   2023-11-02         0.823912      1.000000       0.999851        0.001898
# 2   2023-11-01         0.824287      1.000000       1.000006       -0.001609
# 3   2023-10-31         0.822878      1.012431       1.000526       -0.003502
# 4   2023-10-30         0.822007      1.000000       0.999801        0.001999
# ..         ...              ...           ...            ...             ...
# 256 2022-11-10         0.878591      1.000000       1.000043       -0.003364
# 257 2022-11-09         0.879177      1.000000       0.999733        0.000411
# 258 2022-11-08         0.880192      1.000000       0.999880       -0.001812
# 259 2022-11-07         0.875577      2.655471       1.000709       -0.004310
# 260 2022-11-04         0.869013      1.002432       1.000623       -0.001271
#
#      opt_fourier_offset  opt_fourier_cosamp  opt_fourier_cosfreq  \
# 0              0.821073           -0.166832             0.808415
# 1              0.820840           -0.235751             0.971239
# 2              0.820350           -0.420754             0.734517
# 3              0.819682           -0.204354             0.902361
# 4              0.819226            0.288756             1.077513
# ..                  ...                 ...                  ...
# 256            0.882687            0.558161             0.978266
# 257            0.883055           -0.784316             0.954637
# 258            0.883500           -0.673642             0.931588
# 259            0.883853           -0.277282             1.065215
# 260            0.883787           -0.273804             1.025569
#
#      opt_fourier_cosphase  opt_fourier_sinamp  ...       ROC1         ROC5  \
# 0                1.355945           -0.166235  ... -13.417576   -46.868713
# 1                0.675654           -0.236676  ... -29.529883   -52.433173
# 2                0.905955           -0.421449  ...  15.450779    10.620508
# 3                3.675128           -0.203644  ... -37.219043  1993.725383
# 4               -5.749885           -0.289510  ...  20.140879    56.137304
# ..                    ...                 ...  ...        ...          ...
# 256              1.190969            0.558172  ...  28.341245     2.004028
# 257              0.997205           -0.783883  ...  -5.001495    -8.760565
# 258              0.859684            0.672769  ... -21.485189    -6.737630
# 259             -2.101207           -0.278188  ... -16.010738    43.414098
# 260              0.965392           -0.272704  ...  26.870001    62.913808
#
#           ROC20   WILLIAMS14      RSI14       CMO9     DEMA9     TEMA9  \
# 0     -6.257833 -4048.504950  51.687019  -2.674181  0.005986  0.005147
# 1    -38.479160 -5606.709379  52.602051  -0.170413  0.006857  0.006257
# 2    -42.204763 -5592.890455  55.448772   7.610794  0.007728  0.007481
# 3    -45.988930 -4702.776488  54.410492   4.577080  0.007893  0.007798
# 4    130.517454 -4590.726501  59.337534  17.951895  0.008548  0.008914
# ..          ...          ...        ...        ...       ...       ...
# 256  -24.637429 -2086.301348  50.917662   3.205365  0.058241  0.059403
# 257  -48.216737 -1896.283258  43.351927 -16.075630  0.055868  0.055971
# 258  -39.875848 -1890.489695  44.536107 -13.184401  0.059693  0.061401
# 259  -23.686944 -1858.791582  51.712530   4.551587  0.063735  0.067758
# 260   -0.914049 -1830.667276  59.628696  24.932518  0.062158  0.066507
#
#        STOCH14    Close
# 0    51.687019  0.82022
# 1    52.602051  0.82087
# 2    55.448772  0.82290
# 3    54.410492  0.82198
# 4    59.337534  0.82551
# ..         ...      ...
# 256  50.917662  0.87965
# 257  43.351927  0.86560
# 258  44.536107  0.86821
# 259  51.712530  0.88249
# 260  59.628696  0.89516
#
# [261 rows x 28 columns]

# %%
def prepare_for_pred(df: pd.DataFrame, n_lag_features: int = 10):
    df = df.copy()
    df.drop(['t'], axis=1)
    X = []
    
    for col in df.columns:
        if col == 'Date':
            X.append(df[col])
        elif col != 'Close':
            col_lag_features = pd.DataFrame()
            for i in range(n_lag_features):
                lag_feature_name = f'{col}_Lag_{i}'
                col_lag_features[lag_feature_name] = df[col].shift(-i)
            X.append(col_lag_features)
        
    df = pd.concat(X, axis=1)
    df.dropna(inplace=True)
    return df

# %%
input_feats = prepare_for_pred(feats, n_lag_features).iloc[[0]]
input_feats
# Out:
#         Date  opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  \
# 0 2023-11-03               0.823231               0.823912
#
#    opt_sine_offset_Lag_2  opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  \
# 0               0.824287               0.822878               0.822007
#
#    opt_sine_offset_Lag_5  opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  \
# 0               0.822157                0.82136               0.821617
#
#    opt_sine_offset_Lag_8  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.822001  ...      51.687019      52.602051      55.448772
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      54.410492      59.337534      57.736859      60.945372      57.108356
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      50.341368      58.744227
#
# [1 rows x 261 columns]

# %%
input_feats = input_feats.drop(columns=['Date'])
input_feats
# Out:
#    opt_sine_offset_Lag_0  opt_sine_offset_Lag_1  opt_sine_offset_Lag_2  \
# 0               0.823231               0.823912               0.824287
#
#    opt_sine_offset_Lag_3  opt_sine_offset_Lag_4  opt_sine_offset_Lag_5  \
# 0               0.822878               0.822007               0.822157
#
#    opt_sine_offset_Lag_6  opt_sine_offset_Lag_7  opt_sine_offset_Lag_8  \
# 0                0.82136               0.821617               0.822001
#
#    opt_sine_offset_Lag_9  ...  STOCH14_Lag_0  STOCH14_Lag_1  STOCH14_Lag_2  \
# 0               0.821898  ...      51.687019      52.602051      55.448772
#
#    STOCH14_Lag_3  STOCH14_Lag_4  STOCH14_Lag_5  STOCH14_Lag_6  STOCH14_Lag_7  \
# 0      54.410492      59.337534      57.736859      60.945372      57.108356
#
#    STOCH14_Lag_8  STOCH14_Lag_9
# 0      50.341368      58.744227
#
# [1 rows x 260 columns]

# %%
input_feats_scaled = scaler.transform(input_feats)

# %%
input_feats_scaled_reduced = pca.transform(input_feats_scaled)

# %%
preds_scaled = pd.DataFrame()
for i in range(1, n_days_ahead + 1):
    preds_scaled[f'Close_Day_{i}'] = svrs[i-1].predict(input_feats_scaled_reduced)
preds_scaled
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0     0.765338     0.767875     0.734214     0.573266     0.394387

# %%
preds_unscaled = scaler_y.inverse_transform(preds_scaled)

# %%
pd.DataFrame(preds_unscaled, columns=preds_scaled.columns)
# Out:
#    Close_Day_1  Close_Day_2  Close_Day_3  Close_Day_4  Close_Day_5
# 0     0.820694     0.820515     0.819741     0.816875     0.813525

# %%
outfile = 'predictions_T_svr.csv'

# Save the NumPy matrix to the CSV file (append mode)
with open(outfile, 'a') as f:
    np.savetxt(f, preds_unscaled, delimiter=',')
